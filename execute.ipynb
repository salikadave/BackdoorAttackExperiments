# %%
print('notebook for execution')
# Out:
# notebook for execution

# %%
# %cd ..
# %cd content/drive/MyDrive/C597_ADL/attack_new/
# Out:
# /
# /content/drive/MyDrive/C597_ADL/attack_new

# %%
# !ls
# Out:
# activate-env.sh      checkpoint_contam	    contam	   perturbed_image.png	src
# attacks		     chessdoor_pattern.png  data	   readme.md		training_logs
# attacks_crafting.py  config.json	    execute.ipynb  samples		train.py

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Experiment 1:
#
# - Fix perturbation size to 2/255 = 0.0078
# - Vary poisoned samples from [0, 250, 500, 750, 1000, 1500]

# %%
# !python attacks_crafting.py --pert_size=2 --sample_count=250
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# !python train.py --pert_size=2 --sample_count=250 > training_logs/logs_250_2.txt

# %%
# !python attacks_crafting.py --pert_size=2 --sample_count=500
print("Attack crafting complete")
# !python train.py --pert_size=2 --sample_count=500 > training_logs/logs_500_2.txt
print("Training complete")
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# Training complete

# %%
# !python attacks_crafting.py --pert_size=2 --sample_count=750
print("Attack crafting complete")
# !python train.py --pert_size=2 --sample_count=750 > training_logs/logs_750_2.txt
print("Training complete")
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# Training complete

# %%
# !python attacks_crafting.py --pert_size=2 --sample_count=1000
# !python train.py --pert_size=2 --sample_count=1000
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
# Learning rate:  0.001
# Train ACC: 45.172
# Test ACC: 58.730
# Saving..
# Attack success rate: 2.200
#
# Epoch: 1
# Learning rate:  0.001
# Train ACC: 62.698
# Test ACC: 70.560
# Saving..
# Attack success rate: 2.200
#
# Epoch: 2
# Learning rate:  0.001
# Train ACC: 71.860
# Test ACC: 74.990
# Saving..
# Attack success rate: 0.600
#
# Epoch: 3
# Learning rate:  0.001
# Train ACC: 76.516
# Test ACC: 78.200
# Saving..
# Attack success rate: 4.100
#
# Epoch: 4
# Learning rate:  0.001
# Train ACC: 79.720
# Test ACC: 82.250
# Saving..
# Attack success rate: 0.900
#
# Epoch: 5
# Learning rate:  0.001
# Train ACC: 82.064
# Test ACC: 83.890
# Saving..
# Attack success rate: 1.500
#
# Epoch: 6
# Learning rate:  0.001
# Train ACC: 83.450
# ...

# %%
# !mv contam/model_contam.pth contam/model_contam_2_1000.pth

# %%
# !python attacks_crafting.py --pert_size=2 --sample_count=1500
print("Attack crafting complete")
# !python train.py --pert_size=2 --sample_count=1500
print("Training complete")
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
# Learning rate:  0.001
# Train ACC: 43.000
# Test ACC: 53.400
# Saving..
# Attack success rate: 5.500
#
# Epoch: 1
# Learning rate:  0.001
# Train ACC: 59.978
# Test ACC: 66.490
# Saving..
# Attack success rate: 0.700
#
# Epoch: 2
# Learning rate:  0.001
# Train ACC: 68.864
# Test ACC: 75.650
# Saving..
# Attack success rate: 0.500
#
# Epoch: 3
# Learning rate:  0.001
# Train ACC: 74.052
# Test ACC: 80.130
# Saving..
# Attack success rate: 0.100
#
# Epoch: 4
# Learning rate:  0.001
# Train ACC: 77.390
# Test ACC: 81.610
# Saving..
# Attack success rate: 1.800
#
# Epoch: 5
# Learning rate:  0.001
# Train ACC: 79.800
# Test ACC: 82.240
# Saving..
# Attack success rate: 0.500
#
# Epoch: 6
# Learning rate:  0.001
# ...

# %% [markdown]
# # Experiment 2
#
# - Fix Number of Poisoned samples: 500
# - Vary Perturbation Size: 1, 2, 5, 15, 20, 25

# %%
# !python attacks_crafting.py --pert_size=15 --sample_count=500
print("Attack crafting complete")
# !python train.py --pert_size=15 --sample_count=500 > training_logs/logs_500_15.txt
print("Training complete")
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# Training complete

# %%
# !python attacks_crafting.py --pert_size=10 --sample_count=500
print("Attack crafting complete")
# !python train.py --pert_size=10 --sample_count=500 > training_logs/logs_500_10.txt
print("Training complete")
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# Training complete

# %% [markdown]
# ## Experiment 3:
#
# - Vary for 3/255

# %%
# !python attacks_crafting.py --pert_size=20 --sample_count=500
print("Attack crafting complete")
# !python train.py --pert_size=20 --sample_count=500
print("Training complete")
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
# Learning rate:  0.001
# Train ACC: 46.962
# Test ACC: 52.990
# Saving..
# Attack success rate: 98.700
#
# Epoch: 1
# Learning rate:  0.001
# Train ACC: 64.442
# Test ACC: 69.310
# Saving..
# Attack success rate: 99.900
#
# Epoch: 2
# Learning rate:  0.001
# Train ACC: 72.982
# Test ACC: 73.740
# Saving..
# Attack success rate: 99.900
#
# Epoch: 3
# Learning rate:  0.001
# Train ACC: 78.024
# Test ACC: 77.210
# Saving..
# Attack success rate: 100.000
#
# Epoch: 4
# Learning rate:  0.001
# Train ACC: 81.216
# Test ACC: 80.820
# Saving..
# Attack success rate: 100.000
#
# Epoch: 5
# Learning rate:  0.001
# Train ACC: 83.526
# Test ACC: 82.350
# Saving..
# Attack success rate: 100.000
#
# Epoch: 6
# Learning rate:  0.001
# ...

# %% [markdown]
# ## Experiment 3
#
# - Finding Clean model Test Acc and Attack Success Rate

# %%
# !python attacks_crafting.py --pert_size=2 --sample_count=500
print("Attack crafting complete")
print("Training clean model - no poisoning the trainset")
# !python train.py --pert_size=2 --sample_count=500
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Attack crafting complete
# Training clean model - no poisoning the trainset
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
# Learning rate:  0.001
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Train ACC: 42.398
# Test ACC: 51.640
# Saving..
# Attack success rate: 0.500
#
# Epoch: 1
# Learning rate:  0.001
# Train ACC: 61.232
# Test ACC: 65.410
# Saving..
# Attack success rate: 0.300
#
# Epoch: 2
# Learning rate:  0.001
# Train ACC: 71.044
# Test ACC: 69.880
# Saving..
# Attack success rate: 0.000
#
# Epoch: 3
# Learning rate:  0.001
# Train ACC: 76.578
# Traceback (most recent call last):
# ...
